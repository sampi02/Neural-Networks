# %% [markdown]
# # Neural Networks Gas Turbines

# %% [markdown]
# ### The dataset contains 36733 instances of 11 sensor measures aggregated over one hour (by means of average or sum) from a gas turbine. The Dataset includes gas turbine parameters (such as Turbine Inlet Temperature and Compressor Discharge pressure) in addition to the ambient variables.
#
#
# ### Problem statement: predicting turbine energy yield (TEY) using ambient variables as features.

# %%
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
turbines = pd.read_csv('C:\\Users\\User\\Documents\\Datascience_Assignments\Assignment 16 (Neural Networks)\\gas_turbines.csv')

# %%
turbines.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
turbines.shape
# Out:
# (15039, 11)

# %%
turbines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
turbines.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %%
turbines= turbines[['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'CDP', 'CO',
       'NOX', 'TEY']]

# %%
turbines.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
#
#       NOX     TEY
# 0  82.722  114.70
# 1  82.776  114.72
# 2  82.468  114.71
# 3  82.670  114.72
# 4  82.311  114.72

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(turbines['AT'])
# Out:
# (array([ 236., 1297., 1877., 2005., 1880., 2190., 2278., 1884., 1088.,
#          304.]),
#  array([ 0.5223 ,  3.96297,  7.40364, 10.84431, 14.28498, 17.72565,
#         21.16632, 24.60699, 28.04766, 31.48833, 34.929  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(turbines['AT'])
# Out:
# (array([ 236., 1297., 1877., 2005., 1880., 2190., 2278., 1884., 1088.,
#          304.]),
#  array([ 0.5223 ,  3.96297,  7.40364, 10.84431, 14.28498, 17.72565,
#         21.16632, 24.60699, 28.04766, 31.48833, 34.929  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(turbines['TEY'])
# Out:
# (array([ 247., 2671.,  474.,  528., 7145.,  462.,  989., 1215., 1160.,
#          148.]),
#  array([100.17 , 107.614, 115.058, 122.502, 129.946, 137.39 , 144.834,
#         152.278, 159.722, 167.166, 174.61 ]),
#  <BarContainer object of 10 artists>)

# %%
turb_array= turbines.values

# %%
X= turb_array[:,0:10]
Y= turb_array[:,10]

# %%
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2             3             4  \
# count  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04
# mean   4.913654e-16 -1.875504e-14  2.570219e-16  1.511894e-16 -7.559468e-17
# std    1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00
# min   -2.276462e+00 -4.266288e+00 -3.536594e+00 -2.779497e+00 -1.806771e+00
# 25%   -8.392292e-01 -6.706510e-01 -6.796337e-01 -6.266930e-01 -5.091458e-01
# 50%    5.566605e-02 -6.227861e-02  2.277844e-01 -1.854065e-02 -8.075681e-02
# 75%    8.051309e-01  5.772924e-01  7.916582e-01  4.612196e-01  4.228638e-01
# max    2.266234e+00  3.275970e+00  1.528011e+00  4.486233e+00  2.871006e+00
#
#                   5             6             7             8             9
# count  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04  1.503900e+04
# mean  -3.260021e-15  1.640405e-15  1.965462e-16  3.779734e-17  4.233302e-16
# std    1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00
# min   -5.021933e+00 -4.188141e+00 -1.992416e+00 -8.874862e-01 -3.861033e+00
# 25%   -2.540512e-01 -4.101146e-01 -4.354335e-01 -5.015202e-01 -6.578107e-01
# 50%    2.965544e-01  5.712570e-01 -7.011925e-02 -2.620452e-01 -1.518527e-01
# 75%    7.382490e-01  5.928675e-01  4.311680e-01  8.455882e-02  5.486567e-01
# max    1.028678e+00  6.627839e-01  2.700105e+00  1.895949e+01  4.937717e+00

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from keras.optimizers import Adam

# %%
from keras.layers import Dropout
from sklearn.metrics import classification_report, accuracy_score

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 10,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasRegressor(build_fn = create_model,verbose = 0)

# %%
batch_size = [10,20]
epochs = [10,50]
learning_rate = [0.01,0.1]
dropout_rate = [0.0,0.1]
activation_function = ['relu','linear']
init = ['uniform']
neuron1 = [4,8]
neuron2 = [2,4]

# %%
param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# %%
grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,Y)
# Out:
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# [CV 1/5; 1/128] START activation_function=relu, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 1/5; 1/128] END activation_function=relu, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=  17.1s
# [CV 2/5; 1/128] START activation_function=relu, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 2/5; 1/128] END activation_function=relu, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=  17.2s
# [CV 3/5; 1/128] START activation_function=relu, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 3/5; 1/128] END activation_function=relu, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=
with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.0, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 4}
# 1734476160.0,1553002595.1507795 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 2}
# 3423660236.8,3127529341.427714 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 4}
# 3475997670.4,3120790583.579724 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 2}
# 6827660236.8,6276985419.886764 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 4}
# 1742922475110.4,1553268589420.9834 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 2}
# 3388344395366.4,3118568718792.4907 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 4}
# 3453033984819.2,3108653472713.512 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 2}
# 6841458019532.8,6321802668513.974 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 4}
# 118708791705.6,106018981074.3242 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 2}
# 233169287577.6,213442625643.48407 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 4}
# 236940078284.8,212948113252.06873 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 2}
# 467671465984.0,428119035691.5866 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 4}
# 118051286548480.0,106138588796554.69 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 2}
# 233152551321600.0,213918718280508.2 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 4}
# 236332837031116.8,211830752637529.28 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 2}
# 467757600184729.6,427255553459393.9 with: {'activation_function': 'linear', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 4}
# 189624011.2,406953799.1667779 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 2}
# 383165126.4,802507258.561452 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 4}
# 379028868.8,808463619.6365851 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 2}
# 765414185.6,1605580162.7090826 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 4}
# 187711379865.6,402983336387.7628 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 2}
# 380457346662.4,809400186317.0295 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 4}
# 377741313638.4,809122976113.7502 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 2}
# 761256935424.0,1605507278521.2903 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 4}
# 10816770508.8,23210950027.80539 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 2}
# 21674247680.0,46384680542.41242 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 4}
# 21646941081.6,46408027744.80492 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 2}
# 43284933222.4,92546851137.07501 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 4}
# 10813772031590.4,23210761703251.848 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 2}
# 21710053362892.8,46219276865165.336 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 4}
# 21603450408140.8,46386473578530.29 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 2}
# 43229838835712.0,92567715664354.95 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.0, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 4}
# 214007248.0,375347571.2326826 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 2}
# 419238492.8,754573934.8953528 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 4}
# 424365356.8,756011085.1947316 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 2}
# 826254048.0,1508944794.215733 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 4}
# 211861064908.8,375720981318.02716 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 2}
# 410843214643.2,753591823267.8896 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 4}
# 419602386124.8,754622819558.1193 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 2}
# 835108057907.2,1510743560365.4053 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 10, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 4}
# 12121222041.6,21662775134.929348 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 2}
# 23729893580.8,43569251366.442085 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 4}
# 24437899264.0,43230120896.08901 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 2}
# 47614667571.2,87243013119.31543 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 8, 'neuron2': 4}
# 12160033043251.2,21578300153484.258 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 2}
# 23818882200371.2,43342655430310.65 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 4, 'neuron2': 4}
# 24271172665344.0,43231679495778.48 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 2}
# 47613124542464.0,87157991533847.05 with: {'activation_function': 'linear', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 4}

# %% [raw]
# Best : 1271983555739648.0, using {'activation_function': 'relu', 'batch_size': 10, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.1, 'neuron1': 8, 'neuron2': 4}

# %%
def create_model():
    model1 = Sequential()
    model1.add(Dense(8,input_dim = 10,kernel_initializer = 'uniform',activation = 'relu'))
    model1.add(Dropout(0.1))
    model1.add(Dense(4,kernel_initializer = 'uniform',activation = 'relu'))
    model1.add(Dropout(0.1))
    model1.add(Dense(1,activation = 'sigmoid'))
    adam = Adam(lr = 0.1)
    model1.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['accuracy'])
    return model1

# %%
model1 = KerasRegressor(build_fn = create_model,verbose = 0,batch_size = 10,epochs = 50)

# %%
model1.fit(X_standardized,Y)

# %%
Y_predict = model1.predict(X_standardized)

# %%
Y_predict
# Out:
# array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)

# %%
rmse_value = np.sqrt(np.mean((Y_predict-Y)**2))

# %%
rmse_value
# Out:
# 134.1258000120717

# %%
plt.figure(figsize=(10,5))
plt.plot(Y, color= 'red',label= 'Real data')
plt.plot(Y_predict, color='blue', label='Predicted data')
plt.title('Prediction')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.corrcoef(Y_predict,Y)
# Out:
# C:\Users\Sagar\anaconda3\envs\keras\lib\site-packages\numpy\lib\function_base.py:2559: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\Sagar\anaconda3\envs\keras\lib\site-packages\numpy\lib\function_base.py:2560: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# array([[nan, nan],
#        [nan,  1.]])
